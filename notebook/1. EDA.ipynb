# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("data/car_price_prediction.csv")

# %%
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  str
#  3   Manufacturer      19237 non-null  str
#  4   Model             19237 non-null  str
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  str
#  7   Leather interior  19237 non-null  str
#  8   Fuel type         19237 non-null  str
#  9   Engine volume     19237 non-null  str
#  10  Mileage           19237 non-null  str
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  str
#  13  Drive wheels      19237 non-null  str
#  14  Doors             19237 non-null  str
#  15  Wheel             19237 non-null  str
#  16  Color             19237 non-null  str
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), str(13)
# memory usage: 4.0 MB

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(313)

# %%
df_copy=df.copy()

# %%
df_copy.head(10)
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549   751      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098   394       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657     -        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
# 5              Yes    Diesel             2  160931 km        4.0
# 6              Yes    Hybrid           1.8  258909 km        4.0
# 7              Yes    Petrol           2.4  216118 km        4.0
# 8              Yes    Hybrid           2.5  398069 km        4.0
# 9              Yes    Petrol           3.5  128500 km        6.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4
# 5     Automatic        Front  04-May        Left wheel   White        4
# 6     Automatic        Front  04-May        Left wheel   White       12
# 7     Automatic        Front  04-May        Left wheel    Grey       12
# 8     Automatic        Front  04-May        Left wheel   Black       12
# 9     Automatic          4x4  04-May        Left wheel  Silver       12

# %%
df_copy.drop_duplicates(inplace=True)

# %%
df_copy
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 2                   No    Petrol           1.3  200000 km        4.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  04-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May        Left wheel   Black        8
# 2          Variator        Front  04-May  Right-hand drive   Black        2
# 3         Automatic          4x4  04-May        Left wheel   White        0
# 4         Automatic        Front  04-May        Left wheel  Silver        4
# ...             ...          ...     ...               ...     ...      ...
# 19232        Manual         Rear  02-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  04-May        Left wheel     Red        8
# 19234     Automatic        Front  04-May        Left wheel    Grey        4
# 19235     Automatic        Front  04-May        Left wheel   Black        4
# 19236     Automatic        Front  04-May        Left wheel   White       12
#
# [18924 rows x 18 columns]

# %%
df_copy.reset_index(inplace=True)
df_copy
# Out:
#        index        ID  Price  Levy   Manufacturer    Model  Prod. year  \
# 0          0  45654403  13328  1399          LEXUS   RX 450        2010
# 1          1  44731507  16621  1018      CHEVROLET  Equinox        2011
# 2          2  45774419   8467     -          HONDA      FIT        2006
# 3          3  45769185   3607   862           FORD   Escape        2011
# 4          4  45809263  11726   446          HONDA      FIT        2014
# ...      ...       ...    ...   ...            ...      ...         ...
# 18919  19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999
# 18920  19233  45778856  15681   831        HYUNDAI   Sonata        2011
# 18921  19234  45804997  26108   836        HYUNDAI   Tucson        2010
# 18922  19235  45793526   5331  1288      CHEVROLET  Captiva        2007
# 18923  19236  45813273    470   753        HYUNDAI   Sonata        2012
#
#         Category Leather interior Fuel type Engine volume    Mileage  \
# 0           Jeep              Yes    Hybrid           3.5  186005 km
# 1           Jeep               No    Petrol             3  192000 km
# 2      Hatchback               No    Petrol           1.3  200000 km
# 3           Jeep              Yes    Hybrid           2.5  168966 km
# 4      Hatchback              Yes    Petrol           1.3   91901 km
# ...          ...              ...       ...           ...        ...
# 18919      Coupe              Yes       CNG     2.0 Turbo  300000 km
# 18920      Sedan              Yes    Petrol           2.4  161600 km
# 18921       Jeep              Yes    Diesel             2  116365 km
# 18922       Jeep              Yes    Diesel             2   51258 km
# 18923      Sedan              Yes    Hybrid           2.4  186923 km
#
#        Cylinders Gear box type Drive wheels   Doors             Wheel   Color  \
# 0            6.0     Automatic          4x4  04-May        Left wheel  Silver
# 1            6.0     Tiptronic          4x4  04-May        Left wheel   Black
# 2            4.0      Variator        Front  04-May  Right-hand drive   Black
# 3            4.0     Automatic          4x4  04-May        Left wheel   White
# 4            4.0     Automatic        Front  04-May        Left wheel  Silver
# ...          ...           ...          ...     ...               ...     ...
# 18919        4.0        Manual         Rear  02-Mar        Left wheel  Silver
# 18920        4.0     Tiptronic        Front  04-May        Left wheel     Red
# 18921        4.0     Automatic        Front  04-May        Left wheel    Grey
# 18922        4.0     Automatic        Front  04-May        Left wheel   Black
# 18923        4.0     Automatic        Front  04-May        Left wheel   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 18919        5
# 18920        8
# 18921        4
# 18922        4
# 18923       12
#
# [18924 rows x 19 columns]

# %%
df["Levy"].unique()
# Out:
# <ArrowStringArray>
# [ '1399',  '1018',     '-',   '862',   '446',   '891',   '761',   '751',
#    '394',  '1053',
#  ...
#   '1171',  '1365',  '1531',  '1590', '11706',  '2308',  '4860',  '1641',
#   '1045',  '1901']
# Length: 559, dtype: str

# %%
df["Levy"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        1399
# 1        1018
# 2           -
# 3         862
# 4         446
#          ...
# 19232       -
# 19233     831
# 19234     836
# 19235    1288
# 19236     753
# Name: Levy, Length: 19237, dtype: str>

# %%
df["Levy"]=df["Levy"].replace("-",np.nan)

# %%
df["Levy"]=df["Levy"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              13418 non-null  float64
#  3   Manufacturer      19237 non-null  str
#  4   Model             19237 non-null  str
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  str
#  7   Leather interior  19237 non-null  str
#  8   Fuel type         19237 non-null  str
#  9   Engine volume     19237 non-null  str
#  10  Mileage           19237 non-null  str
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  str
#  13  Drive wheels      19237 non-null  str
#  14  Doors             19237 non-null  str
#  15  Wheel             19237 non-null  str
#  16  Color             19237 non-null  str
#  17  Airbags           19237 non-null  int64
# dtypes: float64(2), int64(4), str(12)
# memory usage: 4.0 MB

# %%
df.head()
# Out:
#          ID  Price    Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399.0        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018.0    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     NaN        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862.0         FORD   Escape        2011       Jeep
# 4  45809263  11726   446.0        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
df["Engine volume"].unique()
# Out:
# <ArrowStringArray>
# [      '3.5',         '3',       '1.3',       '2.5',         '2',       '1.8',
#        '2.4',         '4',       '1.6',       '3.3',
#  ...
#        '6.4',       '3.9', '5.7 Turbo',       '0.9', '0.4 Turbo', '5.4 Turbo',
#  '0.3 Turbo',       '5.2',       '5.8', '1.1 Turbo']
# Length: 107, dtype: str

# %%
df_copy.drop(columns=["ID"],inplace=True)

# %%
df_copy=df_copy.drop(columns=["index"])

# %%
df_copy
# Out:
#        Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399          LEXUS   RX 450        2010       Jeep
# 1      16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2       8467     -          HONDA      FIT        2006  Hatchback
# 3       3607   862           FORD   Escape        2011       Jeep
# 4      11726   446          HONDA      FIT        2014  Hatchback
# ...      ...   ...            ...      ...         ...        ...
# 18919   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 18920  15681   831        HYUNDAI   Sonata        2011      Sedan
# 18921  26108   836        HYUNDAI   Tucson        2010       Jeep
# 18922   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 18923    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 2                   No    Petrol           1.3  200000 km        4.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# ...                ...       ...           ...        ...        ...
# 18919              Yes       CNG     2.0 Turbo  300000 km        4.0
# 18920              Yes    Petrol           2.4  161600 km        4.0
# 18921              Yes    Diesel             2  116365 km        4.0
# 18922              Yes    Diesel             2   51258 km        4.0
# 18923              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  04-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May        Left wheel   Black        8
# 2          Variator        Front  04-May  Right-hand drive   Black        2
# 3         Automatic          4x4  04-May        Left wheel   White        0
# 4         Automatic        Front  04-May        Left wheel  Silver        4
# ...             ...          ...     ...               ...     ...      ...
# 18919        Manual         Rear  02-Mar        Left wheel  Silver        5
# 18920     Tiptronic        Front  04-May        Left wheel     Red        8
# 18921     Automatic        Front  04-May        Left wheel    Grey        4
# 18922     Automatic        Front  04-May        Left wheel   Black        4
# 18923     Automatic        Front  04-May        Left wheel   White       12
#
# [18924 rows x 17 columns]

# %%
plt.figure(figsize=(20,15))
sns.countplot(data=df_copy,x="Manufacturer",palette="Set2")
plt.xticks(rotation=45)
plt.show()

# %%
df_copy["Manufacturer"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                LEXUS
# 1            CHEVROLET
# 2                HONDA
# 3                 FORD
# 4                HONDA
#              ...
# 18919    MERCEDES-BENZ
# 18920          HYUNDAI
# 18921          HYUNDAI
# 18922        CHEVROLET
# 18923          HYUNDAI
# Name: Manufacturer, Length: 18924, dtype: str>

# %%
sns.pairplot(df_copy)
